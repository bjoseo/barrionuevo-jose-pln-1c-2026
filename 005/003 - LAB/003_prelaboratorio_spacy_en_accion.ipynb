# %% [markdown]
# # Prelaboratorio: spaCy en acción sobre una noticia
#
# **Duración estimada:** 25 minutos
#
# ## Propósito
# Este notebook funciona como puente entre los materiales introductorios y el laboratorio integrador. Vas a repasar el pipeline completo de `spaCy` sobre una noticia breve y a practicar una lectura crítica de los resultados.
#
# ## Prerrequisitos
# - Haber recorrido `000_intro_pln_y_spacy.ipynb`, `001_spacy_fundamentos.ipynb` y `002_spacy_pipeline_y_apoyo.ipynb`.
# - Manejar listas, diccionarios y comprensiones básicas en Python.

# %% [markdown]
# ## Modalidad sugerida: trabajo con IA como copiloto cognitivo
#
# En esta materia la IA forma parte del dispositivo pedagógico. Podés usar un asistente de IA para:
# - anticipar qué entidades o verbos podrían aparecer;
# - proponer una estrategia de análisis;
# - explicarte una salida que no entendiste;
# - auditar una interpretación que te parezca dudosa.
#
# **Importante:** la IA procesa patrones, pero no decide por vos. La lectura final de los resultados tiene que ser humana, situada y justificada.

# %%
#!pip install spacy pandas matplotlib wordcloud -q
#!python -m spacy download es_core_news_lg -q

# %%
import spacy
import pandas as pd
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from spacy import displacy

plt.style.use('seaborn-v0_8-darkgrid')
pd.set_option('display.max_colwidth', None)

nlp = spacy.load("es_core_news_sm")
print("Entorno configurado correctamente.")
# Out:
# Entorno configurado correctamente.

# %% [markdown]
# ## 1. Repaso rápido: qué herramientas ya conoces
#
# Antes de mirar la noticia, recuperá estas ideas:
# - tokenización: cómo se segmenta el texto;
# - lematización: cómo se lleva cada palabra a una forma base;
# - POS: cómo se etiqueta la función gramatical;
# - NER: cómo se detectan entidades del mundo real;
# - dependencias: cómo se vinculan las palabras entre sí.

# %% [markdown]
# ## 2. Demostración: un pipeline completo con spaCy
#
# Vamos a trabajar con un texto breve de estilo periodístico. Antes de ejecutarlo, podés pedirle a un asistente de IA que anticipe:
# - qué personas y organizaciones cree que van a aparecer;
# - qué verbos podrían ser centrales;
# - qué errores posibles podría cometer el modelo.

# %%
print("Cargando modelo de spaCy para español...")
print(f"Componentes del pipeline: {nlp.pipe_names}\n")

texto_noticia = (
    "El presidente Javier Milei anunció ayer en Casa Rosada un nuevo plan de inversiones por "
    "500 millones de dólares. Microsoft Argentina y Mercado Libre serán las primeras empresas "
    "en participar. María González, ministra de Tecnología, destacó que el proyecto generará "
    "3.000 empleos en Buenos Aires y Córdoba durante 2025."
)

print("--- Texto a analizar ---")
print(texto_noticia)

doc = nlp(texto_noticia)
print(f"\nTexto procesado: se encontraron {len(doc)} tokens.")
# Out:
# Cargando modelo de spaCy para español...
# Componentes del pipeline: ['tok2vec', 'morphologizer', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
#
# --- Texto a analizar ---
# El presidente Javier Milei anunció ayer en Casa Rosada un nuevo plan de inversiones por 500 millones de dólares. Microsoft Argentina y Mercado Libre serán las primeras empresas en participar. María González, ministra de Tecnología, destacó que el proyecto generará 3.000 empleos en Buenos Aires y Córdoba durante 2025.
#
# Texto procesado: se encontraron 54 tokens.

# %% [markdown]
# ### 2.1 Tokenización detallada
#
# En esta salida conviene observar no solo el token, sino también el lema, la categoría gramatical y si el modelo lo considera una stopword.

# %%
print("--- Análisis de los primeros 12 tokens ---")
print(f"{'Token':<18} {'Lema':<18} {'POS':<10} {'Stopword?':<12} {'Puntuación?'}")
print("-" * 75)

for token in doc[:12]:
    print(
        f"{token.text:<18} {token.lemma_:<18} {token.pos_:<10} "
        f"{'Si' if token.is_stop else 'No':<12} {'Si' if token.is_punct else 'No'}"
    )
# Out:
# --- Análisis de los primeros 12 tokens ---
# Token              Lema               POS        Stopword?    Puntuación?
# ---------------------------------------------------------------------------
# El                 el                 DET        Si           No
# presidente         presidente         NOUN       No           No
# Javier             Javier             PROPN      No           No
# Milei              Milei              PROPN      No           No
# anunció            anunciar           VERB       No           No
# ayer               ayer               ADV        No           No
# en                 en                 ADP        Si           No
# Casa               Casa               PROPN      No           No
# Rosada             Rosada             PROPN      No           No
# un                 uno                DET        Si           No
# nuevo              nuevo              ADJ        Si           No
# plan               plan               NOUN       No           No

# %% [markdown]
# ### 2.2 Reconocimiento de entidades nombradas
#
# El valor pedagógico de esta parte no está solo en detectar entidades, sino también en discutirlas. Si alguna clasificación te resulta extraña, no la tomes como un fracaso del ejercicio: tomala como una oportunidad de análisis.

# %%
entidades_data = []
for ent in doc.ents:
    entidades_data.append({
        'Texto': ent.text,
        'Tipo': ent.label_,
        'Explicación': spacy.explain(ent.label_),
    })

df_entidades = pd.DataFrame(entidades_data)

print("--- Entidades nombradas detectadas ---")
if not df_entidades.empty:
    print(df_entidades.to_string(index=False))
else:
    print("No se encontraron entidades en el texto.")
# Out:
# --- Entidades nombradas detectadas ---
#               Texto Tipo                                                                  Explicación
#        Javier Milei  PER                                                      Named person or family.
#         Casa Rosada  LOC                          Non-GPE locations, mountain ranges, bodies of water
# Microsoft Argentina MISC Miscellaneous entities, e.g. events, nationalities, products or works of art
#       Mercado Libre  LOC                          Non-GPE locations, mountain ranges, bodies of water
#      María González  PER                                                      Named person or family.
#          Tecnología  PER                                                      Named person or family.
#        Buenos Aires  LOC                          Non-GPE locations, mountain ranges, bodies of water
#             Córdoba  LOC                          Non-GPE locations, mountain ranges, bodies of water

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">El presidente
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Javier Milei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  anunció ayer en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Casa Rosada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  un nuevo plan de inversiones por 500 millones de dólares.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft Argentina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  y
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mercado Libre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  serán las primeras empresas en participar.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     María González
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , ministra de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tecnología
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , destacó que el proyecto generará 3.000 empleos en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buenos Aires
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Córdoba
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  durante 2025.</div></span>

# %% [markdown]
# **Pausa crítica**
#
# Elegí una entidad de la tabla y respondé:
# - La clasificación te parece adecuada?
# - Qué evidencia del texto la sostiene?
# - Qué podría haber confundido al modelo?

# %% [markdown]
# Microsoft Argentina, Mercado Libre y Tecnología no están bien clasificadas.
# El modelo se confundio porque las entidades entán enmayúsculas

# %% [markdown]
# ### 2.3 Acciones y estructura sintáctica
#
# Ahora vamos a mirar verbos y dependencias para entender mejor qué acciones aparecen y cómo se organiza la primera oración.

# %%
verbos = [token.lemma_.lower() for token in doc if token.pos_ == "VERB" and not token.is_stop]
verbos_freq = Counter(verbos)

print("--- Verbos principales ---")
if verbos:
    print(verbos_freq.most_common(5))
else:
    print("No se encontraron verbos relevantes.")

primera_oracion = list(doc.sents)[0]
print("\n--- Primera oración ---")
print(primera_oracion)
# Out:
# --- Verbos principales ---
# [('anunciar', 1), ('participar', 1), ('destacar', 1), ('generar', 1)]
#
# --- Primera oración ---
# El presidente Javier Milei anunció ayer en Casa Rosada un nuevo plan de inversiones por 500 millones de dólares.

# %%
displacy.render(primera_oracion, style='dep', jupyter=True, options={'distance': 120, 'compact': True})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="32861269d8ba4df1a59527ab4569413f-0" class="displacy" width="2330" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">El</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">presidente</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Javier</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Milei</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">anunció</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">ayer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Casa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">Rosada</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">un</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">nuevo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">plan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">inversiones</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">500</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">millones</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">dólares.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-32861269d8ba4df1a59527ab4569413f-0-0" stroke-width="2px" d="M62,182.0 62,162.0 164.0,162.0 164.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-32861269d8ba4df1a59527ab4569413f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,184.0 L58,176.0 66,176.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-32861269d8ba4df1a59527ab4569413f-0-1" stroke-width="2px" d="M182,182.0 182,142.0 527.0,142.0 527.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-32861269d8ba4df1a59527ab4569413f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M182,184.0 L178,176.0 186,176.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-32861269d8ba4df1a59527ab4569413f-0-2" stroke-width="2px" d="M182,182.0 182,162.0 284.0,162.0 284.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-32861269d8ba4df1a59527ab4569413f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M284.0,184.0 L288.0,176.0 280.0,176.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-32861269d8ba4df1a59527ab4569413f-0-3" stroke-width="2px" d="M302,182.0 302,162.0 404.0,162.0 404.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-32861269d8ba4df1a59527ab4569413f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M404.0,184.0 L408.0,176.0 400.0,176.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-32861269d8ba4df1a59527ab4569413f-0-4" stroke-width="2px" d="M542,182.0 542,162.0 644.0,162.0 644.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-32861269d8ba4df1a59527ab4569413f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M644.0,184.0 L648.0,176.0 640.0,176.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displa

# %% [markdown]
# ## 3. Extracción de palabras clave
#
# En esta parte vamos a sintetizar el texto mediante palabras clave. La idea no es reemplazar la lectura humana, sino construir una primera capa de interpretación.

# %%
palabras_clave = [
    token.lemma_.lower()
    for token in doc
    if token.is_alpha and not token.is_stop and len(token.text) > 2 and token.pos_ in ['NOUN', 'VERB', 'PROPN']
]

frecuencia_palabras = Counter(palabras_clave)

print("--- Top 5 palabras clave ---")
for palabra, freq in frecuencia_palabras.most_common(5):
    print(f"- {palabra}: {freq}")
# Out:
# --- Top 5 palabras clave ---
# - presidente: 1
# - javier: 1
# - milei: 1
# - anunciar: 1
# - casa: 1

# %% [markdown]
# ### 3.1 Visualización rápida
#
# La nube de palabras te ofrece una vista panorámica. Mirala como apoyo, no como conclusión final.

# %%
if frecuencia_palabras:
    wordcloud = WordCloud(
        width=800,
        height=400,
        background_color='white',
        colormap='viridis',
        max_words=50,
    ).generate_from_frequencies(frecuencia_palabras)

    fig, ax = plt.subplots(figsize=(12, 6))
    ax.imshow(wordcloud, interpolation='bilinear')
    ax.set_title('Palabras clave de la noticia', fontsize=16)
    ax.axis('off')
    plt.show()
else:
    print("No hay suficientes palabras para generar la nube.")

# %% [markdown]
# ## 4. Adelanto del laboratorio integrador
#
# En el próximo notebook vas a construir un analizador de noticias más completo. La diferencia es que ya no vas a trabajar con un ejemplo resuelto, sino con un laboratorio con huecos para completar.
#
# **Modalidad de trabajo del laboratorio:** pair programming con IA.
#
# En esta cátedra, eso significa que la díada de trabajo está formada por vos y un asistente de IA. La IA puede proponer, explicar, depurar y contrastar, pero no reemplaza tu criterio ni tu responsabilidad sobre el resultado.

# %% [markdown]
# ## 5. Antes de pasar al laboratorio
#
# Comprobá si podés hacer estas tres cosas:
# 1. explicar qué información nueva agrega `spaCy` a un texto;
# 2. identificar una salida discutible del modelo y justificar por qué;
# 3. usar un asistente de IA para formular una hipótesis y después contrastarla con la salida real.
#
# **Microbitácora sugerida**
# - Qué le pediste a la IA?
# - Qué parte de la respuesta te resultó útil?
# - Qué corregiste o descartaste?
# - Qué aprendiste al comparar la predicción con la ejecución del notebook?

# %% [markdown]
# La librería `spaCy` además de generar un objeto llamado Doc que funciona como una enciclopedia de datos para cada palabra.
#
# ```
# Información Morfológica (El "DNI" de la palabra)
# Información Semántica y de Referencia
# Información Sintáctica (El "Mapa de Relaciones")
# Información de Fronteras y Estructura
# ```
#
# ```
# Propiedad          Valor agregado por spaCy
# .text                "glucosa" (el original)"
# .lemma_              "glucosa"
# .pos_                NOUN
# .dep_                obj (objeto directo)
# .ent_type_           CHEMICAL o FOOD (dependiendo del modelo)
# .is_stop             False (no es una palabra vacía)
# ```
#
#
# Una salida discutible del modelo es la asignación de etiquetas, puede confundir palabras en mayúsculas que son organizaciones con pronombres personales.

# %% [markdown]
# ## Hipótesis
#
# con la siguiente oración vamos a formular la hipótesis de procesamiento (lo que esperamos que pase)
#
# texto_noticia = ("En la última década, Slack y Zoom transformaron el trabajo, pero hoy el modelo híbrido genera tensiones entre los líderes y sus equipos.")

# %% [markdown]
# ### Predicciones
#
# El modelo identificará Slack y Zoom como organizaciones ORG.
# La palabra `tranformaron` será lematizado como `transformar` y se etiquetará como verbo VERB.
#
#
# ```
# Elemento           Resultado Esperado       Posible "Salida Discutible"
# Slack / Zoom        ORG (Organización)      Que Zoom pase como texto plano (sustantivo).
# trabajo             NOUN (Sustantivo)       Que lo etiquete como VERB.
# híbrido             ADJ (Adjetivo)          Que intente forzarlo como una Entidad.                                      Slack y Zoom        Sujeto                  Que solo tome a Zoom como sujeto y deje a Slack colgado.
#
# ```

# %%
print("Cargando modelo de spaCy para español...")
print(f"Componentes del pipeline: {nlp.pipe_names}\n")

texto_noticia = ("En la última década, Slack y Zoom transformaron el trabajo, pero hoy el modelo híbrido genera tensiones entre los líderes y sus equipos.")

print("--- Texto a analizar ---")
print(texto_noticia)

doc = nlp(texto_noticia)
print(f"\nTexto procesado: se encontraron {len(doc)} tokens.")
# Out:
# Cargando modelo de spaCy para español...
# Componentes del pipeline: ['tok2vec', 'morphologizer', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
#
# --- Texto a analizar ---
# En la última década, Slack y Zoom transformaron el trabajo, pero hoy el modelo híbrido genera tensiones entre los líderes y sus equipos.
#
# Texto procesado: se encontraron 26 tokens.

# %% [markdown]
# ### Tokenización detallada

# %%
print("--- Análisis de los primeros 18 tokens ---")
print(f"{'Token':<18} {'Lema':<18} {'POS':<18} {'Stopword?':<18} {'Puntuación?'}")
print("-" * 75)

for token in doc[:18]:
    print(
        f"{token.text:<18} {token.lemma_:<18} {token.pos_:<18} "
        f"{'Si' if token.is_stop else 'No':<18} {'Si' if token.is_punct else 'No':<18}"
    )
# Out:
# --- Análisis de los primeros 18 tokens ---
# Token              Lema               POS                Stopword?          Puntuación?
# ---------------------------------------------------------------------------
# En                 en                 ADP                Si                 No
# la                 el                 DET                Si                 No
# última             último             ADJ                Si                 No
# década             década             NOUN               No                 No
# ,                  ,                  PUNCT              No                 Si
# Slack              Slack              PROPN              No                 No
# y                  y                  CCONJ              Si                 No
# Zoom               Zoom               PROPN              No                 No
# transformaron      transformar        VERB               No                 No
# el                 el                 DET                Si                 No
# trabajo            trabajo            NOUN               No                 No
# ,                  ,                  PUNCT              No                 Si
# pero               pero               CCONJ              Si                 No
# hoy                hoy                ADV                Si                 No
# el                 el                 DET                Si                 No
# modelo             modelo             NOUN               No                 No
# híbrido            híbrido            ADJ                No                 No
# genera             generar            VERB               No                 No

# %% [markdown]
# ### Reconocimiento de entidades nombradas

# %%
entidades_data = []
for ent in doc.ents:
    entidades_data.append({
        'Texto': ent.text,
        'Tipo': ent.label_,
        'Explicación': spacy.explain(ent.label_),
    })

df_entidades = pd.DataFrame(entidades_data)

print("--- Entidades nombradas detectadas ---")
if not df_entidades.empty:
    print(df_entidades.to_string(index=False))
else:
    print("No se encontraron entidades en el texto.")
# Out:
# --- Entidades nombradas detectadas ---
# Texto Tipo                                                                  Explicación
# Slack MISC Miscellaneous entities, e.g. events, nationalities, products or works of art
#  Zoom  PER                                                      Named person or family.

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">En la última década,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Slack
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  y
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zoom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  transformaron el trabajo, pero hoy el modelo híbrido genera tensiones entre los líderes y sus equipos.</div></span>

# %% [markdown]
# ### Acciones y estructura sintáctica

# %%
verbos = [token.lemma_.lower() for token in doc if token.pos_ == "VERB" and not token.is_stop]
verbos_freq = Counter(verbos)

print("--- Verbos principales ---")
if verbos:
    print(verbos_freq.most_common(5))
else:
    print("No se encontraron verbos relevantes.")

primera_oracion = list(doc.sents)[0]
print("\n--- Primera oración ---")
print(primera_oracion)
# Out:
# --- Verbos principales ---
# [('transformar', 1), ('generar', 1)]
#
# --- Primera oración ---
# En la última década, Slack y Zoom transformaron el trabajo, pero hoy el modelo híbrido genera tensiones entre los líderes y sus equipos.

# %%
displacy.render(primera_oracion, style='dep', jupyter=True, options={'distance': 120, 'compact': True})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="ecea080f30d7468ab4fce068aabfce66-0" class="displacy" width="2810" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">En</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">última</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">década,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Slack</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">y</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Zoom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">transformaron</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">el</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">trabajo,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">pero</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">hoy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">el</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">modelo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">híbrido</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">genera</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">tensiones</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">entre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">los</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">líderes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">y</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">sus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">equipos.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ecea080f30d7468ab4fce068aabfce66-0-0" stroke-width="2px" d="M62,302.0 62,242.0 404.0,242.0 404.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ecea080f30d7468ab4fce068aabfce66-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ecea080f30d7468ab4fce068aabfce66-0-1" stroke-width="2px" d="M182,302.0 182,262.0 401.0,262.0 401.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ecea080f30d7468ab4fce068aabfce66-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M182,304.0 L178,296.0 186,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ecea080f30d7468ab4fce068aabfce66-0-2" stroke-width="2px" d="M302,302.0 302,282.0 398.0,282.0 398.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ecea080f30d7468ab4fce068aabfce66-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M302,304.0 L298,296.0 306,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ecea080f30d7468ab4fce068aabfce66-0-3" stroke-width="2px" d="M422,302.0 422,222.0 887.0,222.0 887.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em

# %% [markdown]
# ### Extracción de palabras clave

# %%
palabras_clave = [
    token.lemma_.lower()
    for token in doc
    if token.is_alpha and not token.is_stop and len(token.text) > 2 and token.pos_ in ['NOUN', 'VERB', 'PROPN']
]

frecuencia_palabras = Counter(palabras_clave)

print("--- Top 5 palabras clave ---")
for palabra, freq in frecuencia_palabras.most_common(5):
    print(f"- {palabra}: {freq}")
# Out:
# --- Top 5 palabras clave ---
# - década: 1
# - slack: 1
# - zoom: 1
# - transformar: 1
# - trabajo: 1

# %%
if frecuencia_palabras:
    wordcloud = WordCloud(
        width=800,
        height=400,
        background_color='white',
        colormap='viridis',
        max_words=50,
    ).generate_from_frequencies(frecuencia_palabras)

    fig, ax = plt.subplots(figsize=(12, 6))
    ax.imshow(wordcloud, interpolation='bilinear')
    ax.set_title('Palabras clave de la noticia', fontsize=16)
    ax.axis('off')
    plt.show()
else:
    print("No hay suficientes palabras para generar la nube.")

# %% [markdown]
# Le pedi al asistente las predicciones sobre una oracion determinada.
# la predicción de `Slack / Zoom` como ORG (Organización) es correcta, el modelo lo tomo como texto plano (sustantivo).
# para `trabajo` la predicción y el modelo coincidieron NOUN (Sustantivo).
# para `híbrido` la predicción y el modelo coincidieron ADJ (Adjetivo).
#
# Al comparar lo que esperábamos (la hipótesis) con lo que el modelo realmente hizo, detectamos que el modelo tiene una fuga de contexto, no entiende palabras que casi siempre son entidades-
